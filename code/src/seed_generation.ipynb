# %% [markdown]
# Seed 0, 1, 2, 3

# %%
import numpy as np

rng = np.random.default_rng(seed=2025) 

operational_seeds = rng.integers(low=0, high=10000, size=6)
operational_seeds
# Out:
# array([4474, 9944, 9925, 3820, 9535, 8271])
